# %%
import pandas as pd

# %%
df0_protien = pd.read_csv("../data/amp-parkinsons-disease-progression-prediction/train_proteins.csv")
df0_protien
# Out:
#          visit_id  visit_month  patient_id UniProt       NPX
# 0            55_0            0          55  O00391   11254.3
# 1            55_0            0          55  O00533  732430.0
# 2            55_0            0          55  O00584   39585.8
# 3            55_0            0          55  O14498   41526.9
# 4            55_0            0          55  O14773   31238.0
# ...           ...          ...         ...     ...       ...
# 232736  58648_108          108       58648  Q9UBX5   27387.8
# 232737  58648_108          108       58648  Q9UHG2  369437.0
# 232738  58648_108          108       58648  Q9UKV8  105830.0
# 232739  58648_108          108       58648  Q9Y646   21257.6
# 232740  58648_108          108       58648  Q9Y6R7   17953.1
#
# [232741 rows x 5 columns]

# %%
df0_peptides = pd.read_csv("../data/amp-parkinsons-disease-progression-prediction/train_peptides.csv")
df0_peptides
# Out:
#          visit_id  visit_month  patient_id UniProt  \
# 0            55_0            0          55  O00391
# 1            55_0            0          55  O00533
# 2            55_0            0          55  O00533
# 3            55_0            0          55  O00533
# 4            55_0            0          55  O00533
# ...           ...          ...         ...     ...
# 981829  58648_108          108       58648  Q9UHG2
# 981830  58648_108          108       58648  Q9UKV8
# 981831  58648_108          108       58648  Q9Y646
# 981832  58648_108          108       58648  Q9Y6R7
# 981833  58648_108          108       58648  Q9Y6R7
#
#                                        Peptide  PeptideAbundance
# 0                                NEQEQPLGQWHLS          11254.30
# 1                                  GNPEPTFSWTK         102060.00
# 2                              IEIPSSVQQVPTIIK         174185.00
# 3       KPQSAVYSTGSNGILLC(UniMod_4)EAEGEPQPTIK          27278.90
# ...

# %%
df0_clinical_train = pd.read_csv("../data/amp-parkinsons-disease-progression-prediction/train_clinical_data.csv")
df0_clinical_train
# Out:
#       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 0         55_0          55            0     10.0      6.0     15.0      NaN
# 1         55_3          55            3     10.0      7.0     25.0      NaN
# 2         55_6          55            6      8.0     10.0     34.0      NaN
# 3         55_9          55            9      8.0      9.0     30.0      0.0
# 4        55_12          55           12     10.0     10.0     41.0      0.0
# ...        ...         ...          ...      ...      ...      ...      ...
# 2610  65043_48       65043           48      7.0      6.0     13.0      0.0
# 2611  65043_54       65043           54      4.0      8.0     11.0      1.0
# 2612  65043_60       65043           60      6.0      6.0     16.0      1.0
# 2613  65043_72       65043           72      3.0      9.0     14.0      1.0
# 2614  65043_84       65043           84      7.0      9.0     20.0      3.0
#
#      upd23b_clinical_state_on_medication
# ...

# %%
df0_clinical_suppl = pd.read_csv("../data/amp-parkinsons-disease-progression-prediction/supplemental_clinical_data.csv")
df0_clinical_suppl
# Out:
#       visit_id  patient_id  visit_month  updrs_1  updrs_2  updrs_3  updrs_4  \
# 0         35_0          35            0      5.0      3.0     16.0      0.0
# 1        35_36          35           36      6.0      4.0     20.0      0.0
# 2         75_0          75            0      4.0      6.0     26.0      0.0
# 3        75_36          75           36      1.0      8.0     38.0      0.0
# 4        155_0         155            0      NaN      NaN      0.0      NaN
# ...        ...         ...          ...      ...      ...      ...      ...
# 2218   65382_0       65382            0      NaN      NaN      0.0      NaN
# 2219   65405_0       65405            0      5.0     16.0     31.0      0.0
# 2220   65405_5       65405            5      NaN      NaN     57.0      NaN
# 2221   65530_0       65530            0     10.0      6.0     24.0      0.0
# 2222  65530_36       65530           36      8.0      4.0     15.0      4.0
#
#      upd23b_clinical_state_on_medication
# ...

# %%
df0_protien['visit_id'].nunique(),\
df0_peptides['visit_id'].nunique(),\
df0_clinical_train['visit_id'].nunique(),\
df0_clinical_suppl['visit_id'].nunique()
# Out:
# (1113, 1113, 2615, 2223)

# %%
df0_protien['UniProt'].unique()
# Out:
# array(['O00391', 'O00533', 'O00584', 'O14498', 'O14773', 'O14791',
#        'O15240', 'O15394', 'O43505', 'O60888', 'O75144', 'O75326',
#        'O94919', 'P00441', 'P00450', 'P00734', 'P00736', 'P00738',
#        'P00746', 'P00747', 'P00748', 'P00751', 'P01008', 'P01009',
#        'P01011', 'P01019', 'P01023', 'P01024', 'P01031', 'P01033',
#        'P01034', 'P01042', 'P01344', 'P01591', 'P01608', 'P01621',
#        'P01717', 'P01780', 'P01833', 'P01834', 'P01857', 'P01859',
#        'P01860', 'P01861', 'P01876', 'P01877', 'P02452', 'P02647',
#        'P02649', 'P02652', 'P02655', 'P02656', 'P02671', 'P02675',
#        'P02679', 'P02747', 'P02748', 'P02749', 'P02750', 'P02751',
#        'P02753', 'P02760', 'P02763', 'P02765', 'P02766', 'P02768',
#        'P02774', 'P02787', 'P02790', 'P04004', 'P04075', 'P04156',
#        'P04180', 'P04196', 'P04207', 'P04211', 'P04216', 'P04217',
#        'P04275', 'P04406', 'P04433', 'P05060', 'P05067', 'P05090',
# ...
